# %% [markdown]
# python programlama dilinde print komutu ekrandan kulanıcıya veren birkoddur.
# 06.08.2024-Veri Yapıları ve Algoritmalar dersi ilk kodlama çıktısıdır
# İGU İSTKA SİBER AKADEMİ MERKEZİ-

# %%
print("Merhaba, iGU - İSTKA!") # print ekrana cıktı veren bır koddur .
# Out:
# Merhaba, iGU - İSTKA!

# %%
import sys # import python proramlama dılınde yazılma kutuphane eklemeye yarayan bir kod blogudur
print (sys.version)
# Out:
# 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/VERIYAPILARI_ISTKA')
! pwd # bize kodun çıktısını dosya yolu olarak veren kod blogudur.
# Out:
# /content/drive/My Drive/VERIYAPILARI_ISTKA
